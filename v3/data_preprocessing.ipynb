# %%
import pandas as pd
df=pd.read_csv("New_volume_forecast_with_sectorial_variational_appending_by_Ulas.csv",sep=";")
df
# Out:
#                                  FCOPERID    datetime      CELL  \
# 0        E302BBF16BA481458B54787E601EFC25  2019-10-02  KRKTP17L
# 1        E302BBF16BA481458B54787E601EFC25  2019-10-03  KRKTP17L
# 2        E302BBF16BA481458B54787E601EFC25  2019-10-04  KRKTP17L
# 3        E302BBF16BA481458B54787E601EFC25  2019-10-05  KRKTP17L
# 4        E302BBF16BA481458B54787E601EFC25  2019-10-06  KRKTP17L
# ...                                   ...         ...       ...
# 4918843  E302BBF16BA481458B54787E601EFC25  2021-12-27  ZAKUM37L
# 4918844  E302BBF16BA481458B54787E601EFC25  2021-12-28  ZAKUM37L
# 4918845  E302BBF16BA481458B54787E601EFC25  2021-12-29  ZAKUM37L
# 4918846  E302BBF16BA481458B54787E601EFC25  2021-12-30  ZAKUM37L
# 4918847  E302BBF16BA481458B54787E601EFC25  2021-12-31  ZAKUM37L
#
#          forecasteddlprbutilbh  actualdlprbutilbh  forecastedtputbh  \
# 0                          NaN                NaN               NaN
# 1                          NaN                NaN               NaN
# 2                          NaN                NaN               NaN
# 3                          NaN                NaN               NaN
# 4                          NaN                NaN               NaN
# ...                        ...                ...               ...
# 4918843              29.222239              71.52         24.899002
# 4918844              29.222239              69.51         24.899002
# 4918845              29.222239              70.03         24.899002
# 4918846              29.222239              75.93         24.899002
# 4918847              29.222239              62.21         24.899002
#
#          actualdltputbh
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 4918843          13.166
# 4918844          15.281
# 4918845          10.509
# 4918846          13.901
# 4918847          13.431
#
# [4918848 rows x 7 columns]

# %%
import numpy as np
df=df[["CELL","actualdlprbutilbh","actualdltputbh"]].drop_duplicates()
df=df.replace([np.inf, -np.inf], np.nan)
df = df.drop(df.index[df['actualdltputbh'] < 0])
df = df.drop(df.index[df['actualdlprbutilbh'] < 0])
df=df.dropna(subset=['actualdlprbutilbh',"CELL","actualdltputbh"], how="any")

# %%
df.describe()
# Out:
#        actualdlprbutilbh  actualdltputbh
# count       2.090487e+06    2.090487e+06
# mean        3.956718e+01    1.999539e+01
# std         2.538467e+01    1.514766e+01
# min         3.400000e-01    0.000000e+00
# 25%         1.831000e+01    9.754000e+00
# 50%         3.582000e+01    1.660400e+01
# 75%         5.810000e+01    2.606900e+01
# max         9.998000e+01    1.293000e+03

# %%
df.to_csv(r"data.csv")
df=pd.read_csv("data.csv")
df
# Out:
#          Unnamed: 0      CELL  actualdlprbutilbh  actualdltputbh
# 0               475  KRKTP17L               0.82          39.898
# 1               476  KRKTP17L              21.75          37.131
# 2               477  KRKTP17L              20.55          29.267
# 3               478  KRKTP17L              20.09          19.557
# 4               479  KRKTP17L              20.47          31.294
# ...             ...       ...                ...             ...
# 2090482     4918843  ZAKUM37L              71.52          13.166
# 2090483     4918844  ZAKUM37L              69.51          15.281
# 2090484     4918845  ZAKUM37L              70.03          10.509
# 2090485     4918846  ZAKUM37L              75.93          13.901
# 2090486     4918847  ZAKUM37L              62.21          13.431
#
# [2090487 rows x 4 columns]

# %%
d=pd.read_csv("result_with_split.csv")
d
# Out:
#    Unnamed: 0        Method Name  \
# 0           0  Lineer Regression
# 1           1          Curve Fit
# 2           2             Powell
#
#                                        Total MSE  \
# 0  300852081015107845825562254280733874978816.00
# 1                                     3229639.40
# 2            35671801796424156844246804987904.00
#
#                                  Average MSE  Total MAPE  Average MAPE  \
# 0  57878430360736406555059823931203518464.00   422938.32         81.37
# 1                                     -52.68   308114.47       -614.72
# 2            6862601345983870261312618496.00   187983.28         36.16
#
#    Total Time Passed
# 0           6.308279
# 1          10.412758
# 2          29.740383

# %%
import pandas as pd
import numpy as np
e=pd.read_csv("results_Curve_Fit_3D.csv",index_col=False)
e=e[e.MAPE!="-"]

# %%
e
# Out:
#    Unnamed: 0      Cell     MSE    Passed  MAPE
# 1           3  CESRT44L   87.21  0.000000  7.49
# 2           1  CPMIG32L  133.25  0.000000  9.55
# 3           2  KATADB3L   63.83  0.000000  6.26

# %%
e.MSE.mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:1622, in _ensure_numeric(x)
#    1621 try:
# -> 1622     x = float(x)
#    1623 except (TypeError, ValueError):
#    1624     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: '87.21133.2563.83'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:1626, in _ensure_numeric(x)
#    1625 try:
# -> 1626     x = complex(x)
#    1627 except ValueError as err:
#    1628     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 e.MSE.mean()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:11119, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11101 @doc(
#   11102     _num_doc,
#   11103     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11117     **kwargs,
#   11118 ):
# > 11119     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:10689, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10681 def mean(
#   10682     self,
#   10683     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   10687     **kwargs,
#   10688 ) -> Series | float:
# > 10689     return self._stat_function(
#   10690         "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10691     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:10641, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10631     warnings.warn(
#   10632         "Using the level keyword in DataFrame and Series aggregations is "
#   10633         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   10636         stacklevel=find_stack_level(),
#   10637     )
#   10638     return self._agg_by_level(
#   10639         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   10640     )
# > 10641 return self._reduce(
#   10642     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10643 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:4471, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4467     raise NotImplementedError(
#    4468         f"Series.{name} does not implement {kwd_name}."
#    4469     )
#    4470 with np.errstate(all="ignore"):
# -> 4471     return op(delegate, skipna=skipna, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      91 try:
#      92     with np.errstate(invalid="ignore"):
# ---> 93         return f(*args, **kwargs)
#      94 except ValueError as e:
#      95     # we want to transform an object array
#      96     # ValueError message to the more typical TypeError
#      97     # e.g. this is normally a disallowed function on
#      98     # object arrays that contain strings
#      99     if is_object_dtype(args[0]):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:410, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     407 if datetimelike and mask is None:
#     408     mask = isna(values)
# --> 410 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412 if datetimelike:
#     413     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:698, in nanmean(values, axis, skipna, mask)
#     695     dtype_count = dtype
#     697 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 698 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     700 if axis is not None and getattr(the_sum, "ndim", False):
#     701     count = cast(np.ndarray, count)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\nanops.py:1629, in _ensure_numeric(x)
#    1626             x = complex(x)
#    1627         except ValueError as err:
#    1628             # e.g. "foo"
# -> 1629             raise TypeError(f"Could not convert {x} to numeric") from err
#    1630 return x
#
# TypeError: Could not convert 87.21133.2563.83 to numeric

# %%
e.Passed.astype("float64").sum()
# Out:
# 11.812345
